# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Stacy Kiriiri
# * Student pace: Part time
# * Scheduled project review date/time: 24th July 2023
# * Instructor name: Asha Deen
# * Blog post URL:

# %% [markdown]
# ## Microsoft-Movie-Analysis
# Here, I'm going to do an exploratory data analysis on various datasets to extract insights and identify trends in the movie production industry for Microsoft.

# %% [markdown]
# ## Accessing the Data with Pandas

# %%
#importing the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#load the datasets
#first dataframe
df = pd.read_csv('zippedData/imdb.title.basics.csv.gz')
df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
#second dataframe
df1 = pd.read_csv('zippedData/imdb.title.ratings.csv.gz')
df1.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
#third dataframe
df2 = pd.read_csv('zippedData/bom.movie_gross.csv.gz')
df2.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %% [markdown]
# ## Methods and Attributes to access data information

# %%
#concise summary of the dataframes
#first dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
#second dataframe
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
#third dataframe
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
#first dataframe
df.columns
# Out:
# Index(['tconst', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres'],
#       dtype='object')

# %%
#second dataframe
df1.columns
# Out:
# Index(['tconst', 'averagerating', 'numvotes'], dtype='object')

# %%
#third dataframe
df2.columns
# Out:
# Index(['title', 'studio', 'domestic_gross', 'foreign_gross', 'year'], dtype='object')

# %%
#return data types of all columns in the dataframes
#first dataframe
df.dtypes
# Out:
# tconst              object
# primary_title       object
# original_title      object
# start_year           int64
# runtime_minutes    float64
# genres              object
# dtype: object

# %%
#second dataframe
df1.dtypes
# Out:
# tconst            object
# averagerating    float64
# numvotes           int64
# dtype: object

# %%
#third dataframe
df2.dtypes
# Out:
# title              object
# studio             object
# domestic_gross    float64
# foreign_gross      object
# year                int64
# dtype: object

# %%
#first dataframe
df.shape
# Out:
# (146144, 6)

# %%
#second dataframe
df1.shape
# Out:
# (73856, 3)

# %%
#third dataframe
df2.shape
# Out:
# (3387, 5)

# %% [markdown]
# ## Statistical Methods

# %%
#summary statistic for the dataframes
#second dataframe
df1.describe()
# Out:
#        averagerating      numvotes
# count   73856.000000  7.385600e+04
# mean        6.332729  3.523662e+03
# std         1.474978  3.029402e+04
# min         1.000000  5.000000e+00
# 25%         5.500000  1.400000e+01
# 50%         6.500000  4.900000e+01
# 75%         7.400000  2.820000e+02
# max        10.000000  1.841066e+06

# %%
#third dataframe
df2.describe()
# Out:
#        domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %%
#investigating why the column 'foreign_gross' in df2 statistics has not been calculated
df2['foreign_gross'].sample(n=20)
# Out:
# 202      4000000
# 2644         NaN
# 1595     6300000
# 2760     1,010.0
# 1724         NaN
# 2240         NaN
# 1726     1200000
# 1201    48800000
# 886      5800000
# 568      2600000
# 845      8700000
# 1334         NaN
# 2258         NaN
# 1713         NaN
# 892     11600000
# 810     28100000
# 833          NaN
# 819     14400000
# 3249         NaN
# 1754         NaN
# Name: foreign_gross, dtype: object

# %%
#checking for missing values in df2
df2.isna().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %% [markdown]
# ## Dealing with missing data

# %%
#looking out for missing data in the dataframes
#first dataframe
df.isna().sum()
# Out:
# tconst                 0
# primary_title          0
# original_title        21
# start_year             0
# runtime_minutes    31739
# genres              5408
# dtype: int64

# %%
#second dataframe
df1.isna().sum()
# Out:
# tconst           0
# averagerating    0
# numvotes         0
# dtype: int64

# %%
#third dataframe
df2.isna().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
#determining the percentage of rows in the 'runtime_minutes' column in df(the first dataframe) that contain missing values
print(len(df[df.runtime_minutes.isna()])/ len(df))
# Out:
# 0.21717620976571053

# %%
#dropping the column 'runtime_minutes' in df as it will have no impact in my analysis
#first dataframe
df=df.drop("runtime_minutes", axis=1)
df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year                genres
# 0        2013    Action,Crime,Drama
# 1        2019       Biography,Drama
# 2        2018                 Drama
# 3        2018          Comedy,Drama
# 4        2017  Comedy,Drama,Fantasy

# %%
#first dataframe
df.isna().sum()
# Out:
# tconst               0
# primary_title        0
# original_title      21
# start_year           0
# genres            5408
# dtype: int64

# %%
#dropping the remaining missing values from the first dataframe by dropping rows
df = df.dropna()
df
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146138  tt9916428                          The Secret of China
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
#first dataframe
df.isna().sum()
# Out:
# tconst            0
# primary_title     0
# original_title    0
# start_year        0
# genres            0
# dtype: int64

# %%
#second dataframe
df1.isna().sum()
# Out:
# tconst           0
# averagerating    0
# numvotes         0
# dtype: int64

# %%
#third dataframe
df2.isna().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
#determining the percentage of rows in the 'foreign_gross' column in df2(the third dataframe) that contain missing values
print(len(df2[df2.foreign_gross.isna()])/ len(df2))
# Out:
# 0.3985828166519043

# %%
df2 = df2.dropna()
df2
# Out:
#                                                   title        studio  \
# 0                                           Toy Story 3            BV
# 1                            Alice in Wonderland (2010)            BV
# 2           Harry Potter and the Deathly Hallows Part 1            WB
# 3                                             Inception            WB
# 4                                   Shrek Forever After          P/DW
# ...                                                 ...           ...
# 3275                                    I Still See You           LGF
# 3286                              The Catcher Was a Spy           IFC
# 3309                                         Time Freak    Grindstone
# 3342  Reign of Judges: Title of Liberty - Concept Short  Darin Southa
# 3353            Antonio Lopez 1970: Sex Fashion & Disco            FM
#
#       domestic_gross foreign_gross  year
# 0        415000000.0     652000000  2010
# 1        334200000.0     691300000  2010
# ...

# %%
#third dataframe
df2.isna().sum()
# Out:
# title             0
# studio            0
# domestic_gross    0
# foreign_gross     0
# year              0
# dtype: int64

# %% [markdown]
# ## Combining Dataframes

# %%
#merging df(first dataframe) and df1(second dataframe) based on a common key
#setting the 'tconst' column in df and df1 as the index_column
df.set_index('tconst', inplace=True)
df.head()
# Out:
#                              primary_title              original_title  \
# tconst
# tt0063540                        Sunghursh                   Sunghursh
# tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# tt0069049       The Other Side of the Wind  The Other Side of the Wind
# tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#            start_year                genres
# tconst
# tt0063540        2013    Action,Crime,Drama
# tt0066787        2019       Biography,Drama
# tt0069049        2018                 Drama
# tt0069204        2018          Comedy,Drama
# tt0100275        2017  Comedy,Drama,Fantasy

# %%
df1.set_index('tconst', inplace=True)
df1.head()
# Out:
#             averagerating  numvotes
# tconst
# tt10356526            8.3        31
# tt10384606            8.9       559
# tt1042974             6.4        20
# tt1043726             4.2     50352
# tt1060240             6.5        21

# %%
df_df1 = df.join(df1, how='inner')
df_df1.head()
# Out:
#                              primary_title              original_title  \
# tconst
# tt0063540                        Sunghursh                   Sunghursh
# tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# tt0069049       The Other Side of the Wind  The Other Side of the Wind
# tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#            start_year                genres  averagerating  numvotes
# tconst
# tt0063540        2013    Action,Crime,Drama            7.0        77
# tt0066787        2019       Biography,Drama            7.2        43
# tt0069049        2018                 Drama            6.9      4517
# tt0069204        2018          Comedy,Drama            6.1        13
# tt0100275        2017  Comedy,Drama,Fantasy            6.5       119
